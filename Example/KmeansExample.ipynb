# %% [markdown]
# <a href="https://colab.research.google.com/github/ederquesado/kmeans/blob/master/KmeansExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import seaborn as sns
 import matplotlib.pyplot as plt
 import pandas as pd
 # %matplotlib inline

# %%
import numpy as np

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=50)

# %%
type(data)
# Out:
# tuple

# %%
plt.figure(figsize=[12,8])
plt.scatter(data[0][:,0], data[0][:,1], c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-2.37178661, 10.27788487],
#        [ 0.11584155, -5.37562512],
#        [-1.94847438,  5.20472404],
#        [-5.64892498, -2.38445033]])

# %%
kmeans.labels_
# Out:
# array([0, 1, 2, 0, 3, 1, 0, 1, 1, 3, 3, 0, 3, 2, 3, 2, 0, 0, 3, 3, 3, 2,
#        0, 0, 0, 2, 0, 1, 2, 0, 0, 3, 3, 1, 1, 3, 3, 3, 2, 2, 0, 3, 2, 2,
#        1, 1, 0, 2, 2, 0, 1, 3, 2, 0, 2, 2, 1, 3, 3, 2, 1, 1, 0, 1, 1, 0,
#        1, 2, 0, 0, 1, 3, 2, 1, 2, 2, 3, 2, 2, 1, 3, 2, 3, 3, 3, 3, 0, 1,
#        0, 3, 1, 0, 1, 2, 2, 3, 1, 2, 1, 2, 3, 1, 2, 0, 2, 1, 2, 1, 3, 0,
#        1, 3, 0, 0, 3, 2, 0, 0, 2, 1, 0, 2, 0, 0, 1, 0, 0, 2, 2, 1, 3, 1,
#        1, 2, 0, 2, 1, 0, 0, 3, 0, 2, 2, 1, 3, 0, 1, 2, 1, 3, 0, 3, 2, 1,
#        1, 2, 0, 1, 1, 1, 2, 2, 1, 1, 3, 3, 3, 2, 1, 1, 1, 1, 3, 2, 1, 2,
#        3, 1, 0, 2, 1, 2, 2, 0, 3, 1, 3, 0, 2, 1, 2, 2, 3, 2, 1, 0, 3, 2,
#        3, 0], dtype=int32)

# %%
f, (ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(12,8))
ax1.set_title('KMeans')
ax1.scatter(data[0][:,0], data[0][:,1], c=kmeans.labels_,cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1],cmap='rainbow')
